# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/USER/Downloads/FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = 'latin')
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.groupby('Item')['Y2014'].sum()
# Out:
# Item
# Alcohol, Non-Food        2403.00
# Alcoholic Beverages    102410.11
# Animal Products         11935.65
# Animal fats            209460.54
# Apples and products      9499.23
#                          ...
# Vegetables, Other      155038.96
# Vegetal Products       107145.19
# Wheat and products     232670.13
# Wine                     4497.36
# Yams                   200396.96
# Name: Y2014, Length: 119, dtype: float64

# %%
#What is the total sum of Animal Fat produced in 2014 and 2017? Ans: 209460.54 and 269617.53
df.groupby('Item')['Y2017'].sum()
# Out:
# Item
# Alcohol, Non-Food        2348.00
# Alcoholic Beverages     95581.06
# Animal Products         11547.65
# Animal fats            269617.53
# Apples and products     10198.90
#                          ...
# Vegetables, Other      157752.59
# Vegetal Products       107655.20
# Wheat and products     240047.62
# Wine                     4178.02
# Yams                   229174.59
# Name: Y2017, Length: 119, dtype: float64

# %%
#What is the mean and Standard deviation across the whole dataset for the year 2015 to 3 decimal places? Ans: 135.236 and 1603.404
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
#What is the total number and percentage of missing data in 2016 to 2 decimal place? Ans: 1535 and 2.52
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                column_name  percent_missing
# Area Code        Area Code         0.000000
# Area                  Area         0.000000
# Item Code        Item Code         0.000000
# Item                  Item         0.000000
# Element Code  Element Code         0.000000
# Element            Element         0.000000
# Unit                  Unit         0.000000
# Y2014                Y2014         2.607354
# Y2015                Y2015         2.540078
# Y2016                Y2016         2.518747
# Y2017                Y2017         2.471162
# Y2018                Y2018         2.356300

# %%
percent_missing = df.isnull().sum()
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                column_name  percent_missing
# Area Code        Area Code                0
# Area                  Area                0
# Item Code        Item Code                0
# Item                  Item                0
# Element Code  Element Code                0
# Element            Element                0
# Unit                  Unit                0
# Y2014                Y2014             1589
# Y2015                Y2015             1548
# Y2016                Y2016             1535
# Y2017                Y2017             1506
# Y2018                Y2018             1436

# %%
#Which year had the highest sum of Import Quality? Ans: 2018
df.groupby('Element')['Y2014'].count()
# Out:
# Element
# Domestic supply quantity                  5244
# Export Quantity                           3660
# Fat supply quantity (g/capita/day)        4965
# Feed                                      1216
# Food                                      4896
# Food supply (kcal/capita/day)             4947
# Food supply quantity (kg/capita/yr)       4860
# Import Quantity                           4919
# Losses                                    2009
# Other uses (non-food)                     1662
# Processing                                1987
# Production                                3830
# Protein supply quantity (g/capita/day)    4963
# Residuals                                 4604
# Seed                                       762
# Stock Variation                           4230
# Total Population - Both sexes               45
# Tourist consumption                        555
# Name: Y2014, dtype: int64

# %%
df.groupby('Element')['Y2015'].count()
# Out:
# Element
# Domestic supply quantity                  5245
# Export Quantity                           3704
# Fat supply quantity (g/capita/day)        4974
# Feed                                      1177
# Food                                      4901
# Food supply (kcal/capita/day)             4955
# Food supply quantity (kg/capita/yr)       4865
# Import Quantity                           4911
# Losses                                    2009
# Other uses (non-food)                     1667
# Processing                                1995
# Production                                3828
# Protein supply quantity (g/capita/day)    4971
# Residuals                                 4605
# Seed                                       759
# Stock Variation                           4229
# Total Population - Both sexes               45
# Tourist consumption                        555
# Name: Y2015, dtype: int64

# %%
df.groupby('Element')['Y2017'].count()
# Out:
# Element
# Domestic supply quantity                  5258
# Export Quantity                           3660
# Fat supply quantity (g/capita/day)        4982
# Feed                                      1213
# Food                                      4912
# Food supply (kcal/capita/day)             4965
# Food supply quantity (kg/capita/yr)       4876
# Import Quantity                           4929
# Losses                                    2009
# Other uses (non-food)                     1619
# Processing                                1998
# Production                                3829
# Protein supply quantity (g/capita/day)    4980
# Residuals                                 4618
# Seed                                       758
# Stock Variation                           4231
# Total Population - Both sexes               45
# Tourist consumption                        555
# Name: Y2017, dtype: int64

# %%
df.groupby('Element')['Y2018'].count()
# Out:
# Element
# Domestic supply quantity                  5256
# Export Quantity                           3646
# Fat supply quantity (g/capita/day)        4987
# Feed                                      1225
# Food                                      4913
# Food supply (kcal/capita/day)             4969
# Food supply quantity (kg/capita/yr)       4877
# Import Quantity                           4945
# Losses                                    2008
# Other uses (non-food)                     1655
# Processing                                2003
# Production                                3846
# Protein supply quantity (g/capita/day)    4986
# Residuals                                 4616
# Seed                                       758
# Stock Variation                           4217
# Total Population - Both sexes               45
# Tourist consumption                        555
# Name: Y2018, dtype: int64

# %%
df.groupby('Element')['Y2016'].count()
# Out:
# Element
# Domestic supply quantity                  5250
# Export Quantity                           3653
# Fat supply quantity (g/capita/day)        4980
# Feed                                      1215
# Food                                      4910
# Food supply (kcal/capita/day)             4963
# Food supply quantity (kg/capita/yr)       4874
# Import Quantity                           4908
# Losses                                    2009
# Other uses (non-food)                     1634
# Processing                                1996
# Production                                3838
# Protein supply quantity (g/capita/day)    4978
# Residuals                                 4610
# Seed                                       759
# Stock Variation                           4231
# Total Population - Both sexes               45
# Tourist consumption                        555
# Name: Y2016, dtype: int64

# %%
#What is the total number of the sum of Production in 2014? Ans: 1931287.75
df.groupby('Element')['Y2014'].sum()
# Out:
# Element
# Domestic supply quantity                  1996716.35
# Export Quantity                            150020.64
# Fat supply quantity (g/capita/day)          10225.56
# Feed                                       216927.89
# Food                                      1212332.49
# Food supply (kcal/capita/day)              454257.00
# Food supply quantity (kg/capita/yr)         49650.63
# Import Quantity                            274144.48
# Losses                                     153223.00
# Other uses (non-food)                       78718.13
# Processing                                 282923.00
# Production                                1931287.75
# Protein supply quantity (g/capita/day)      11836.46
# Residuals                                   30149.00
# Seed                                        21922.92
# Stock Variation                             58749.83
# Total Population - Both sexes             1031585.00
# Tourist consumption                           416.00
# ...

# %%
#Which of these elements had the highest sum in 2018? Ans: Domestic Supply quantity
#Which of these elements had the 3rd lowest sum in 2018? Ans: Protein supply quantity(g/capita/day)
df.groupby('Element')['Y2018'].sum()
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %%
#What is the total Import Quantity in Algeria in 2018? Ans: 341729.98
df.groupby('Area')['Y2018'].sum('Import Quantity')
# Out:
# Area
# Algeria                         341729.98
# Angola                          235206.68
# Benin                           124960.70
# Botswana                         23129.08
# Burkina Faso                    112970.72
# Cabo Verde                       14622.60
# Cameroon                        233022.93
# Central African Republic         30101.57
# Chad                             72282.24
# Comoros                             59.84
# Congo                            42005.53
# Côte d'Ivoire                   227018.00
# Djibouti                         23718.96
# Egypt                           852652.92
# Eswatini                         55045.07
# Ethiopia                        450788.86
# Ethiopia PDR                         0.00
# Gabon                            28339.38
# Gambia                           23513.80
# Ghana                           358915.64
# Guinea                          103262.08
# Guinea-Bissau                    18997.92
# ...

# %%
#What is the total number of unique countries in the Dataset? Ans: 49
df.groupby('Area').count()
# Out:
#                              Area Code  Item Code  Item  Element Code  \
# Area
# Algeria                           1313       1313  1313          1313
# Angola                            1424       1424  1424          1424
# Benin                             1285       1285  1285          1285
# Botswana                          1378       1378  1378          1378
# Burkina Faso                      1409       1409  1409          1409
# Cabo Verde                        1260       1260  1260          1260
# Cameroon                          1460       1460  1460          1460
# Central African Republic          1344       1344  1344          1344
# Chad                              1343       1343  1343          1343
# Comoros                             45         45    45            45
# Congo                             1413       1413  1413          1413
# Côte d'Ivoire                     1467       1467  1467          1467
# ...
